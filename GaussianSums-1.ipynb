# %% [markdown]
# <a href="https://colab.research.google.com/github/debmalyabasak/debmalyabasak.github.io/blob/main/GaussianSums-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = int(np.log(X)**5)

# Generate primes in the range [X, 2X]
primes = list(sympy.primerange(X, 2 * X))

# Compute V_p for each prime p
V_real = []
V_imag = []

for p in primes:
    V_real_p = 0
    V_imag_p = 0
    for k in range(1, K + 1):
        legendre = legendre_symbol(k, p)
        theta = -s.imag * np.log(k)  # Extract the imaginary part of s
        magnitude = k ** (-s.real)  # Extract the real part of s
        V_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
        V_imag_p += legendre * magnitude * np.sin(theta)  # Imaginary part: sum of sines
    V_real.append(V_real_p)
    V_imag.append(V_imag_p)

# Analyze the distributions
plt.figure(figsize=(12, 6))

# Histogram for Re(V_p)
plt.subplot(1, 2, 1)
plt.hist(V_real, bins=50, color='blue', alpha=0.7, edgecolor='black')
plt.title("Distribution of Re(V_p)")
plt.xlabel("Re(V_p)")
plt.ylabel("Frequency")

# Histogram for Im(V_p)
plt.subplot(1, 2, 2)
plt.hist(V_imag, bins=50, color='orange', alpha=0.7, edgecolor='black')
plt.title("Distribution of Im(V_p)")
plt.xlabel("Im(V_p)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# Optional: Output basic statistics
print("Basic Statistics for Re(V_p):")
print(f"Mean: {np.mean(V_real):.4f}, Std Dev: {np.std(V_real):.4f}")
print()
print("Basic Statistics for Im(V_p):")
print(f"Mean: {np.mean(V_imag):.4f}, Std Dev: {np.std(V_imag):.4f}")
# Out:
# Enter a large value for X: 50
# Enter the real part of s: 1
# Enter the imaginary part of s: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-b9be0d1528ff> in <cell line: 0>()
#      35 # Histogram for Re(V_p)
#      36 plt.subplot(1, 2, 1)
# ---> 37 plt.hist(V_real, bins=50, color='blue', alpha=0.7, edgecolor='black')
#      38 plt.title("Distribution of Re(V_p)")
#      39 plt.xlabel("Re(V_p)")
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3467     BarContainer | Polygon | list[BarContainer | Polygon],
#    3468 ]:
# -> 3469     return gca().hist(
#    3470         x,
#    3471         bins=bins,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7091             # this will automatically overwrite bins,
#    7092             # so that each histogram uses the same bins
# -> 7093             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7094             tops.append(m)
#    7095         tops = np.array(tops, float)  # causes problems later if it's an int
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, density, weights)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     424             raise ValueError('`bins` must be positive, when an integer')
#     425
# --> 426         first_edge, last_edge = _get_outer_edges(a, range)
#     427
#     428     elif np.ndim(bins) == 1:
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     312             raise ValueError(
#     313                 'max must be larger than min in range parameter.')
# --> 314         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     315             raise ValueError(
#     316                 "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = int(np.log(X)**10)

# Generate primes in the range [X, 2X]
primes = list(sympy.primerange(X, 2 * X))

# Check if there are primes in the range
if not primes:
    print(f"No primes found in the range [{X}, {2*X}]. Please choose a larger value for X.")
else:
    # Compute V_p for each prime p
    V_real = []
    V_imag = []

    for p in primes:
        V_real_p = 0
        V_imag_p = 0
        for k in range(1, K + 1):
            legendre = legendre_symbol(k, p)
            theta = -s.imag * np.log(k)  # Extract the imaginary part of s
            magnitude = k ** (-s.real)  # Extract the real part of s
            V_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            V_imag_p += legendre * magnitude * np.sin(theta)  # Imaginary part: sum of sines
        V_real.append(V_real_p)
        V_imag.append(V_imag_p)

    # Check if V_real and V_imag are non-empty before plotting
    if V_real and V_imag:
        # Analyze the distributions
        plt.figure(figsize=(12, 6))

        # Histogram for Re(V_p)
        plt.subplot(1, 2, 1)
        plt.hist(V_real, bins=50, color='blue', alpha=0.7, edgecolor='black')
        plt.title("Distribution of Re(V_p)")
        plt.xlabel("Re(V_p)")
        plt.ylabel("Frequency")

        # Histogram for Im(V_p)
        plt.subplot(1, 2, 2)
        plt.hist(V_imag, bins=50, color='orange', alpha=0.7, edgecolor='black')
        plt.title("Distribution of Im(V_p)")
        plt.xlabel("Im(V_p)")
        plt.ylabel("Frequency")

        plt.tight_layout()
        plt.show()

        # Optional: Output basic statistics
        print("Basic Statistics for Re(V_p):")
        print(f"Mean: {np.mean(V_real):.4f}, Std Dev: {np.std(V_real):.4f}")
        print()
        print("Basic Statistics for Im(V_p):")
        print(f"Mean: {np.mean(V_imag):.4f}, Std Dev: {np.std(V_imag):.4f}")
    else:
        print("No valid values for V_real or V_imag. Check the inputs or computation.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e18b19997c33> in <cell line: 0>()
#      41         # Histogram for Re(V_p)
#      42         plt.subplot(1, 2, 1)
# ---> 43         plt.hist(V_real, bins=50, color='blue', alpha=0.7, edgecolor='black')
#      44         plt.title("Distribution of Re(V_p)")
#      45         plt.xlabel("Re(V_p)")
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3467     BarContainer | Polygon | list[BarContainer | Polygon],
#    3468 ]:
# -> 3469     return gca().hist(
#    3470         x,
#    3471         bins=bins,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7091             # this will automatically overwrite bins,
#    7092             # so that each histogram uses the same bins
# -> 7093             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7094             tops.append(m)
#    7095         tops = np.array(tops, float)  # causes problems later if it's an int
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, density, weights)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     424             raise ValueError('`bins` must be positive, when an integer')
#     425
# --> 426         first_edge, last_edge = _get_outer_edges(a, range)
#     427
#     428     elif np.ndim(bins) == 1:
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     312             raise ValueError(
#     313                 'max must be larger than min in range parameter.')
# --> 314         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     315             raise ValueError(
#     316                 "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = 100

# Generate 5 random primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
random_primes = random.sample(all_primes, 5)

# Compute S_p for each selected prime p
S_real = []  # Store the real part of S_p for each p

for p in random_primes:
    S_real_p = 0
    for k in range(1, K + 1):
        try:
            legendre = legendre_symbol(k, p)
            theta = -s.imag * np.log(k)  # Extract the imaginary part of s
            magnitude = k ** (-s.real)  # Extract the real part of s
            S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
        except Exception as e:
            print(f"Error at p={p}, k={k}: {e}")
            continue
    S_real.append(S_real_p)

# Plot the real part of S_p as a function of p
plt.figure(figsize=(8, 6))
plt.plot(random_primes, S_real, marker='o', linestyle='-', color='blue')
plt.title("Real Part of S_p vs Primes p")
plt.xlabel("Prime p")
plt.ylabel("Re(S_p)")
plt.grid(True)
plt.show()
# Out:
# Enter a large value for X: 10000
# Enter the real part of s: 2
# Enter the imaginary part of s: 5

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = 100

# Generate 100 random primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
random_primes = random.sample(all_primes, 100)

# Compute S_p for each selected prime p
S_real = []  # Store the real part of S_p for each p

for p in random_primes:
    S_real_p = 0
    for k in range(1, K + 1):
        try:
            legendre = legendre_symbol(k, p)
            theta = -s.imag * np.log(k)  # Extract the imaginary part of s
            magnitude = k ** (-s.real)  # Extract the real part of s
            S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
        except Exception as e:
            print(f"Error at p={p}, k={k}: {e}")
            continue
    S_real.append(S_real_p)

# Plot the real part of S_p as a function of p
plt.figure(figsize=(10, 6))
plt.scatter(random_primes, S_real, color='blue', alpha=0.7)
plt.title("Real Part of S_p vs Primes p")
plt.xlabel("Prime p")
plt.ylabel("Re(S_p)")
plt.grid(True)
plt.show()
# Out:
# Enter a large value for X: 10000
# Enter the real part of s: 1
# Enter the imaginary part of s: 10

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = 100

# Generate primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))

# Check if there are fewer than 10,000 primes
num_primes = len(all_primes)
if num_primes < 10000:
    print(f"Only {num_primes} primes found in the range [{X}, {2 * X}]. Sampling all of them.")
    random_primes = all_primes
else:
    random_primes = random.sample(all_primes, 10000)

# Compute S_p for each selected prime p
S_real = []  # Store the real part of S_p for each p

for p in random_primes:
    S_real_p = 0
    for k in range(1, K + 1):
        try:
            legendre = legendre_symbol(k, p)
            theta = -s.imag * np.log(k)  # Extract the imaginary part of s
            magnitude = k ** (-s.real)  # Extract the real part of s
            S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
        except Exception as e:
            print(f"Error at p={p}, k={k}: {e}")
            continue
    S_real.append(S_real_p)

# Filter out invalid values
S_real = np.array(S_real)
finite_S_real = S_real[np.isfinite(S_real)]

# Check if there are any valid values to plot
if len(finite_S_real) == 0:
    print("No valid data to plot.")
else:
    # Plot histogram of the real part of S_p
    plt.figure(figsize=(10, 6))
    plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
    plt.title("Distribution of Re(S_p)")
    plt.xlabel("Re(S_p)")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

    # Basic statistical analysis
    mean_real = np.mean(finite_S_real)
    std_real = np.std(finite_S_real)
    print(f"Mean of Re(S_p): {mean_real}")
    print(f"Standard deviation of Re(S_p): {std_real}")
# Out:
# Enter a large value for X: 1000000
# Enter the real part of s: 2
# Enter the imaginary part of s: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-16824e59bfd0> in <cell line: 0>()
#      41 # Filter out invalid values
#      42 S_real = np.array(S_real)
# ---> 43 finite_S_real = S_real[np.isfinite(S_real)]
#      44
#      45 # Check if there are any valid values to plot
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = 100

# Generate primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))

# Check if there are fewer than 10,000 primes
num_primes = len(all_primes)
if num_primes < 10000:
    print(f"Only {num_primes} primes found in the range [{X}, {2 * X}]. Sampling all of them.")
    random_primes = all_primes
else:
    random_primes = random.sample(all_primes, 10000)

# Compute S_p for each selected prime p
S_real = []  # Store the real part of S_p for each p

for p in random_primes:
    S_real_p = 0
    for k in range(1, K + 1):
        try:
            legendre = legendre_symbol(k, p)
            theta = -s.imag * np.log(k)  # Extract the imaginary part of s
            magnitude = k ** (-s.real)  # Extract the real part of s
            S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
        except Exception as e:
            print(f"Error at p={p}, k={k}: {e}")
            continue
    S_real.append(S_real_p)

# Ensure all elements in S_real are floats
S_real_float = []
for val in S_real:
    try:
        S_real_float.append(float(val))
    except (TypeError, ValueError):
        print(f"Skipping non-numeric value: {val}")

# Convert to NumPy array for further processing
S_real_float = np.array(S_real_float)

# Filter out invalid (non-finite) values
finite_S_real = S_real_float[np.isfinite(S_real_float)]

# Check if there are any valid values to plot
if len(finite_S_real) == 0:
    print("No valid data to plot.")
else:
    # Plot histogram of the real part of S_p
    plt.figure(figsize=(10, 6))
    plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
    plt.title("Distribution of Re(S_p)")
    plt.xlabel("Re(S_p)")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

    # Basic statistical analysis
    mean_real = np.mean(finite_S_real)
    std_real = np.std(finite_S_real)
    print(f"Mean of Re(S_p): {mean_real}")
    print(f"Standard deviation of Re(S_p): {std_real}")
# Out:
# Enter a large value for X: 10000000
# Enter the real part of s: 0
# Enter the imaginary part of s: 0
# Mean of Re(S_p): 10.1152
# Standard deviation of Re(S_p): 14.688156077602116

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = 100

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Compute S_p for each prime p
S_real = []  # Store the real part of S_p for each p

for p in all_primes:
    S_real_p = 0
    for k in range(1, K + 1):
        try:
            legendre = legendre_symbol(k, p)
            theta = -s.imag * np.log(k)  # Extract the imaginary part of s
            magnitude = k ** (-s.real)  # Extract the real part of s
            S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
        except Exception as e:
            print(f"Error at p={p}, k={k}: {e}")
            continue
    S_real.append(S_real_p)

# Ensure all elements in S_real are floats
S_real_float = []
for val in S_real:
    try:
        S_real_float.append(float(val))
    except (TypeError, ValueError):
        print(f"Skipping non-numeric value: {val}")

# Convert to NumPy array for further processing
S_real_float = np.array(S_real_float)

# Filter out invalid (non-finite) values
finite_S_real = S_real_float[np.isfinite(S_real_float)]

# Check if there are any valid values to plot
if len(finite_S_real) == 0:
    print("No valid data to plot.")
else:
    # Plot histogram of the real part of S_p
    plt.figure(figsize=(10, 6))
    plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
    plt.title("Distribution of Re(S_p)")
    plt.xlabel("Re(S_p)")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

    # Basic statistical analysis
    mean_real = np.mean(finite_S_real)
    std_real = np.std(finite_S_real)
    print(f"Mean of Re(S_p): {mean_real}")
    print(f"Standard deviation of Re(S_p): {std_real}")
# Out:
# Enter a large value for X: 100000
# Enter the real part of s: 0
# Enter the imaginary part of s: 0
# Number of primes in the range [100000, 200000]: 8392
# Mean of Re(S_p): 9.8267397521449
# Standard deviation of Re(S_p): 14.115619874869592

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s_real = float(input("Enter the real part of s: "))
s_imag = float(input("Enter the imaginary part of s: "))
s = complex(s_real, s_imag)
K = 100

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Compute S_p for each prime p
S_real = []  # Store the real part of S_p for each p

for p in all_primes:
    S_real_p = 0
    for k in range(1, K + 1):
        try:
            legendre = legendre_symbol(k, p)
            theta = -s.imag * np.log(k)  # Extract the imaginary part of s
            magnitude = k ** (-s.real)  # Extract the real part of s
            S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
        except Exception as e:
            print(f"Error at p={p}, k={k}: {e}")
            continue
    S_real.append(S_real_p)

# Ensure all elements in S_real are floats
S_real_float = []
for val in S_real:
    try:
        S_real_float.append(float(val))
    except (TypeError, ValueError):
        print(f"Skipping non-numeric value: {val}")

# Convert to NumPy array for further processing
S_real_float = np.array(S_real_float)

# Filter out invalid (non-finite) values
finite_S_real = S_real_float[np.isfinite(S_real_float)]

# Check if there are any valid values to plot
if len(finite_S_real) == 0:
    print("No valid data to plot.")
else:
    # Plot histogram of the real part of S_p
    plt.figure(figsize=(10, 6))
    plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
    plt.title("Distribution of Re(S_p)")
    plt.xlabel("Re(S_p)")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

    # Basic statistical analysis
    mean_real = np.mean(finite_S_real)
    std_real = np.std(finite_S_real)
    print(f"Mean of Re(S_p): {mean_real}")
    print(f"Standard deviation of Re(S_p): {std_real}")
# Out:
# Enter a large value for X: 1000000
# Enter the real part of s: 1
# Enter the imaginary part of s: 5
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p): 1.1902680297978405
# Standard deviation of Re(S_p): 0.7177817806178369

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
K = 100

# Allow the user to input 5 s values
s_values = []
for i in range(1, 6):
    print(f"Enter values for s_{i}:")
    s_real = float(input(f"  Real part of s_{i}: "))
    s_imag = float(input(f"  Imaginary part of s_{i}: "))
    s_values.append(complex(s_real, s_imag))

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Compute and plot for each s value
for idx, s in enumerate(s_values, 1):
    print(f"\nProcessing for s_{idx} = {s}...")

    # Compute S_p for each prime p
    S_real = []  # Store the real part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)

    # Ensure all elements in S_real are floats
    S_real_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value: {val}")

    # Convert to NumPy array for further processing
    S_real_float = np.array(S_real_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]

    # Check if there are any valid values to plot
    if len(finite_S_real) == 0:
        print(f"No valid data to plot for s_{idx}.")
        continue

    # Normalize the histogram data
    density, bins = np.histogram(finite_S_real, bins=100, density=True)
    bin_centers = 0.5 * (bins[:-1] + bins[1:])

    # Plot histogram of the real part of S_p
    plt.figure(figsize=(10, 6))
    plt.plot(bin_centers, density, color='blue', alpha=0.7, label=f's_{idx} = {s}')
    plt.title(f"Normalized Distribution of Re(S_p) for s_{idx} = {s}")
    plt.xlabel("Re(S_p)")
    plt.ylabel("Density")
    plt.grid(True)
    plt.legend()
    plt.show()

    # Basic statistical analysis
    mean_real = np.mean(finite_S_real)
    std_real = np.std(finite_S_real)
    print(f"Mean of Re(S_p) for s_{idx}: {mean_real}")
    print(f"Standard deviation of Re(S_p) for s_{idx}: {std_real}")
# Out:
# Enter a large value for X: 10000000
# Enter values for s_1:
#   Real part of s_1: 0
#   Imaginary part of s_1: 0
# Enter values for s_2:
#   Real part of s_2: 0
#   Imaginary part of s_2: 10
# Enter values for s_3:
#   Real part of s_3: 2
#   Imaginary part of s_3: 5
# Enter values for s_4:
#   Real part of s_4: 1
#   Imaginary part of s_4: -6
# Enter values for s_5:
#   Real part of s_5: -1
#   Imaginary part of s_5: 8
# Number of primes in the range [10000000, 20000000]: 606028
#
# Processing for s_1 = 0j...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-48c201b3bd80> in <cell line: 0>()
#      38             try:
#      39                 legendre = legendre_symbol(k, p)
# ---> 40                 theta = -s.imag * np.log(k)  # Extract the imaginary part of s
#      41                 magnitude = k ** (-s.real)  # Extract the real part of s
#      42                 S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
#
# KeyboardInterrupt:

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
s1_real = float(input("Enter the real part of s1: "))
s1_imag = float(input("Enter the imaginary part of s1: "))
s2_real = float(input("Enter the real part of s2: "))
s2_imag = float(input("Enter the imaginary part of s2: "))
s1 = complex(s1_real, s1_imag)
s2 = complex(s2_real, s2_imag)
K = 100

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Function to compute S_p for a given s
def compute_S_p(s):
    S_real = []  # Store the real part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)

    # Ensure all elements in S_real are floats
    S_real_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value: {val}")

    # Convert to NumPy array for further processing
    S_real_float = np.array(S_real_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]

    return finite_S_real

# Compute S_p for both s1 and s2
finite_S_real_s1 = compute_S_p(s1)
finite_S_real_s2 = compute_S_p(s2)

# Check if there are any valid values to plot
if len(finite_S_real_s1) == 0 or len(finite_S_real_s2) == 0:
    print("No valid data to plot.")
else:
    # Plot histogram of the real part of S_p for s1
    plt.figure(figsize=(10, 6))
    plt.hist(finite_S_real_s1, bins=100, color='blue', alpha=0.7, edgecolor='black')
    plt.title(f"Distribution of Re(S_p) for s = {s1}")
    plt.xlabel("Re(S_p)")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

    # Plot histogram of the real part of S_p for s2
    plt.figure(figsize=(10, 6))
    plt.hist(finite_S_real_s2, bins=100, color='green', alpha=0.7, edgecolor='black')
    plt.title(f"Distribution of Re(S_p) for s = {s2}")
    plt.xlabel("Re(S_p)")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

    # Basic statistical analysis for s1
    mean_real_s1 = np.mean(finite_S_real_s1)
    std_real_s1 = np.std(finite_S_real_s1)
    print(f"Mean of Re(S_p) for s1: {mean_real_s1}")
    print(f"Standard deviation of Re(S_p) for s1: {std_real_s1}")

    # Basic statistical analysis for s2
    mean_real_s2 = np.mean(finite_S_real_s2)
    std_real_s2 = np.std(finite_S_real_s2)
    print(f"Mean of Re(S_p) for s2: {mean_real_s2}")
    print(f"Standard deviation of Re(S_p) for s2: {std_real_s2}")
# Out:
# Enter a large value for X: 1000000
# Enter the real part of s1: 0
# Enter the imaginary part of s1: 0
# Enter the real part of s2: 1
# Enter the imaginary part of s2: 10
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p) for s1: 9.957237169021083
# Standard deviation of Re(S_p) for s1: 14.361978229356533
# Mean of Re(S_p) for s2: 0.9263018713430997
# Standard deviation of Re(S_p) for s2: 0.404297660845649

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
K = 100

# Prompt user for 5 different \( s \)-values
s_values = []
for i in range(1, 6):
    s_real = float(input(f"Enter the real part of s{i}: "))
    s_imag = float(input(f"Enter the imaginary part of s{i}: "))
    s_values.append(complex(s_real, s_imag))

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Function to compute S_p for a given s
def compute_S_p(s):
    S_real = []  # Store the real part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)

    # Ensure all elements in S_real are floats
    S_real_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value: {val}")

    # Convert to NumPy array for further processing
    S_real_float = np.array(S_real_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]

    return finite_S_real

# Compute S_p and plot for each s value
for idx, s in enumerate(s_values, start=1):
    finite_S_real = compute_S_p(s)

    if len(finite_S_real) == 0:
        print(f"No valid data to plot for s{idx} = {s}.")
    else:
        # Plot histogram of the real part of S_p for the current s
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Re(S_p) for s{idx} = {s}")
        plt.xlabel("Re(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_real = np.mean(finite_S_real)
        std_real = np.std(finite_S_real)
        print(f"Mean of Re(S_p) for s{idx}: {mean_real}")
        print(f"Standard deviation of Re(S_p) for s{idx}: {std_real}")
# Out:
# Enter a large value for X: 1000000
# Enter the real part of s1: 0
# Enter the imaginary part of s1: 0
# Enter the real part of s2: 1
# Enter the imaginary part of s2: 10
# Enter the real part of s3: 1
# Enter the imaginary part of s3: 25
# Enter the real part of s4: -1
# Enter the imaginary part of s4: 15
# Enter the real part of s5: 3
# Enter the imaginary part of s5: 17
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p) for s1: 9.957237169021083
# Standard deviation of Re(S_p) for s1: 14.361978229356533
# Mean of Re(S_p) for s2: 0.9263018713430997
# Standard deviation of Re(S_p) for s2: 0.404297660845649
# Mean of Re(S_p) for s3: 0.7675474561910203
# Standard deviation of Re(S_p) for s3: 0.27168100208181817
# Mean of Re(S_p) for s4: 8.424660358708424
# Standard deviation of Re(S_p) for s4: 375.10777437465435
# Mean of Re(S_p) for s5: 1.0009507605999612
# Standard deviation of Re(S_p) for s5: 0.09466228045907758

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
K = 100

# Prompt user for 5 different \( s \)-values
s_values = []
for i in range(1, 6):
    s_real = float(input(f"Enter the real part of s{i}: "))
    s_imag = float(input(f"Enter the imaginary part of s{i}: "))
    s_values.append(complex(s_real, s_imag))

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Function to compute S_p for a given s
def compute_S_p(s):
    S_real = []  # Store the real part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)

    # Ensure all elements in S_real are floats
    S_real_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value: {val}")

    # Convert to NumPy array for further processing
    S_real_float = np.array(S_real_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]

    return finite_S_real

# Compute S_p and plot for each s value
for idx, s in enumerate(s_values, start=1):
    finite_S_real = compute_S_p(s)

    if len(finite_S_real) == 0:
        print(f"No valid data to plot for s{idx} = {s}.")
    else:
        # Plot histogram of the real part of S_p for the current s
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Re(S_p) for s{idx} = {s}")
        plt.xlabel("Re(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_real = np.mean(finite_S_real)
        std_real = np.std(finite_S_real)
        print(f"Mean of Re(S_p) for s{idx}: {mean_real}")
        print(f"Standard deviation of Re(S_p) for s{idx}: {std_real}")
# Out:
# Enter a large value for X: 1000000
# Enter the real part of s1: 3
# Enter the imaginary part of s1: 13
# Enter the real part of s2: -3
# Enter the imaginary part of s2: 8
# Enter the real part of s3: 2
# Enter the imaginary part of s3: 0
# Enter the real part of s4: 4
# Enter the imaginary part of s4: 11
# Enter the real part of s5: 4
# Enter the imaginary part of s5: 25
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p) for s1: 1.0094119093116851
# Standard deviation of Re(S_p) for s1: 0.11509448252037405
# Mean of Re(S_p) for s2: 216313.36335398656
# Standard deviation of Re(S_p) for s2: 1902081.056958255
# Mean of Re(S_p) for s3: 1.0814811233286457
# Standard deviation of Re(S_p) for s3: 0.30144685384980097
# Mean of Re(S_p) for s4: 0.9965721965264627
# Standard deviation of Re(S_p) for s4: 0.01780313166164575
# Mean of Re(S_p) for s5: 0.996108469808649
# Standard deviation of Re(S_p) for s5: 0.009138652549255295

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol  # Updated import
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
K = 100

# Generate 10 different s-values
s_values = []
imaginary_parts = random.sample(range(-20, 21), 9)  # Pick 9 unique random integers between -20 and 20
imaginary_parts.append(0)  # Ensure one value has imaginary part 0
random.shuffle(imaginary_parts)  # Shuffle the list to randomize positions

s_values = [complex(1, imag) for imag in imaginary_parts]

print("Generated s-values:")
for idx, s in enumerate(s_values, start=1):
    print(f"s{idx} = {s}")

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Function to compute S_p for a given s
def compute_S_p(s):
    S_real = []  # Store the real part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)

    # Ensure all elements in S_real are floats
    S_real_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value: {val}")

    # Convert to NumPy array for further processing
    S_real_float = np.array(S_real_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]

    return finite_S_real

# Compute S_p and plot for each s value
for idx, s in enumerate(s_values, start=1):
    finite_S_real = compute_S_p(s)

    if len(finite_S_real) == 0:
        print(f"No valid data to plot for s{idx} = {s}.")
    else:
        # Plot histogram of the real part of S_p for the current s
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Re(S_p) for s{idx} = {s}")
        plt.xlabel("Re(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_real = np.mean(finite_S_real)
        std_real = np.std(finite_S_real)
        print(f"Mean of Re(S_p) for s{idx}: {mean_real}")
        print(f"Standard deviation of Re(S_p) for s{idx}: {std_real}")
# Out:
# Enter a large value for X: 1000000
# Generated s-values:
# s1 = (1+3j)
# s2 = (1-6j)
# s3 = (1+9j)
# s4 = (1+1j)
# s5 = (1+16j)
# s6 = (1-15j)
# s7 = (1-14j)
# s8 = (1-9j)
# s9 = (1-19j)
# s10 = (1+0j)
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p) for s1: 0.9426861727231901
# Standard deviation of Re(S_p) for s1: 0.402309651040536
# Mean of Re(S_p) for s2: 0.9603356418551773
# Standard deviation of Re(S_p) for s2: 0.4153681688830696
# Mean of Re(S_p) for s3: 1.3495736039137423
# Standard deviation of Re(S_p) for s3: 0.8429665335430653
# Mean of Re(S_p) for s4: 0.8298658197392764
# Standard deviation of Re(S_p) for s4: 0.3596761147066803
# Mean of Re(S_p) for s5: 0.7605702628289563
# Standard deviation of Re(S_p) for s5: 0.24834206351521718
# Mean of Re(S_p) for s6: 0.830979141650502
# Standard deviation of Re(S_p) for s6: 0.3028158229966159
# Mean of Re(S_p) for s7: 1.365189523567051
# Standard deviation of Re(S_p) for s7: 0.8639719499522672
# Mean of Re(S_p) for s8: 1.3495736039137423
# Standard deviation of Re(S_p) for s8: 0.8429665335430653
# Mean of Re(S_p) for s9: 0.9778881559165855
# Standard deviation of Re(S_p) for s9: 0.5254255101597978
# Mean of Re(S_p) for s10: 1.547239441603404
# Standard deviation of Re(S_p) for s10: 1.0362491148255721

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
real_part = float(input("Enter the real part of s: "))  # User input for the real part of s
K = 100

# Generate 10 different s-values
s_values = []
imaginary_parts = random.sample(range(-20, 21), 9)  # Pick 9 unique random integers between -20 and 20
imaginary_parts.append(0)  # Ensure one value has imaginary part 0
random.shuffle(imaginary_parts)  # Shuffle the list to randomize positions

s_values = [complex(real_part, imag) for imag in imaginary_parts]

print("Generated s-values:")
for idx, s in enumerate(s_values, start=1):
    print(f"s{idx} = {s}")

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Function to compute S_p for a given s
def compute_S_p(s):
    S_real = []  # Store the real part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)

    # Ensure all elements in S_real are floats
    S_real_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value: {val}")

    # Convert to NumPy array for further processing
    S_real_float = np.array(S_real_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]

    return finite_S_real

# Compute S_p and plot for each s value
for idx, s in enumerate(s_values, start=1):
    finite_S_real = compute_S_p(s)

    if len(finite_S_real) == 0:
        print(f"No valid data to plot for s{idx} = {s}.")
    else:
        # Plot histogram of the real part of S_p for the current s
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Re(S_p) for s{idx} = {s}")
        plt.xlabel("Re(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_real = np.mean(finite_S_real)
        std_real = np.std(finite_S_real)
        print(f"Mean of Re(S_p) for s{idx}: {mean_real}")
        print(f"Standard deviation of Re(S_p) for s{idx}: {std_real}")
# Out:
# Generated s-values:
# s1 = (2-8j)
# s2 = (2+9j)
# s3 = (2+0j)
# s4 = (2-5j)
# s5 = (2+17j)
# s6 = (2-18j)
# s7 = (2+5j)
# s8 = (2-7j)
# s9 = (2+8j)
# s10 = (2-17j)
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p) for s1: 1.0061650892235756
# Standard deviation of Re(S_p) for s1: 0.19914447636779264
# Mean of Re(S_p) for s2: 1.072028933934461
# Standard deviation of Re(S_p) for s2: 0.29038309195763123
# Mean of Re(S_p) for s3: 1.0814811233286457
# Standard deviation of Re(S_p) for s3: 0.30144685384980097
# Mean of Re(S_p) for s4: 1.0503946673858282
# Standard deviation of Re(S_p) for s4: 0.2634639413369584
# Mean of Re(S_p) for s5: 1.0067080712145955
# Standard deviation of Re(S_p) for s5: 0.20076818250849424
# Mean of Re(S_p) for s6: 1.0618350534574057
# Standard deviation of Re(S_p) for s6: 0.27736214611018534
# Mean of Re(S_p) for s7: 1.0503946673858282
# Standard deviation of Re(S_p) for s7: 0.2634639413369584
# Mean of Re(S_p) for s8: 0.9306400713325818
# Standard deviation of Re(S_p) for s8: 0.04693426911776778
# Mean of Re(S_p) for s9: 1.0061650892235756
# Standard deviation of Re(S_p) for s9: 0.19914447636779264
# Mean of Re(S_p) for s10: 1.0067080712145955
# Standard deviation of Re(S_p) for s10: 0.20076818250849424

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
real_part = float(input("Enter the real part of s: "))  # User input for the real part of s
K = 100

# Generate 10 different s-values with imaginary parts between 0 and 50
imaginary_parts = random.sample(range(1, 51), 9)  # Pick 9 unique random integers between 1 and 50
imaginary_parts.append(0)  # Ensure one value is 0
imaginary_parts.sort()  # Sort in increasing order

s_values = [complex(real_part, imag) for imag in imaginary_parts]

print("Generated s-values (sorted by increasing imaginary part):")
for idx, s in enumerate(s_values, start=1):
    print(f"s{idx} = {s}")

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Function to compute S_p for a given s
def compute_S_p(s):
    S_real = []  # Store the real part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)

    # Ensure all elements in S_real are floats
    S_real_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value: {val}")

    # Convert to NumPy array for further processing
    S_real_float = np.array(S_real_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]

    return finite_S_real

# Compute S_p and plot for each s value
for idx, s in enumerate(s_values, start=1):
    finite_S_real = compute_S_p(s)

    if len(finite_S_real) == 0:
        print(f"No valid data to plot for s{idx} = {s}.")
    else:
        # Plot histogram of the real part of S_p for the current s
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Re(S_p) for s{idx} = {s}")
        plt.xlabel("Re(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_real = np.mean(finite_S_real)
        std_real = np.std(finite_S_real)
        print(f"Mean of Re(S_p) for s{idx}: {mean_real}")
        print(f"Standard deviation of Re(S_p) for s{idx}: {std_real}")
# Out:
# Enter a large value for X: 1000000
# Enter the real part of s: 0
# Generated s-values (sorted by increasing imaginary part):
# s1 = 0j
# s2 = 4j
# s3 = 8j
# s4 = 15j
# s5 = 19j
# s6 = 27j
# s7 = 33j
# s8 = 36j
# s9 = 42j
# s10 = 45j
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p) for s1: 9.957237169021083
# Standard deviation of Re(S_p) for s1: 14.361978229356533
# Mean of Re(S_p) for s2: 1.3796898939051019
# Standard deviation of Re(S_p) for s2: 6.179032921420696
# Mean of Re(S_p) for s3: 0.7965960233734434
# Standard deviation of Re(S_p) for s3: 6.033162772581208
# Mean of Re(S_p) for s4: -0.7543882226513527
# Standard deviation of Re(S_p) for s4: 6.16923127579314
# Mean of Re(S_p) for s5: 0.2866182663563819
# Standard deviation of Re(S_p) for s5: 5.976275686387317
# Mean of Re(S_p) for s6: 3.097645244658197
# Standard deviation of Re(S_p) for s6: 7.1143868532915535
# Mean of Re(S_p) for s7: 1.0544037843175962
# Standard deviation of Re(S_p) for s7: 5.8033390462919066
# Mean of Re(S_p) for s8: -0.21579993135154174
# Standard deviation of Re(S_p) for s8: 7.134646177561955
# Mean of Re(S_p) for s9: 0.31957883745183097
# Standard deviation of Re(S_p) for s9: 5.5056575162897845
# Mean of Re(S_p) for s10: 3.810409208461188
# Standard deviation of Re(S_p) for s10: 7.906345273942572

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
real_part = float(input("Enter the real part of s: "))  # User input for the real part of s
K = 100

# Generate 10 different s-values with imaginary parts between 0 and 50
imaginary_parts = random.sample(range(1, 51), 9)  # Pick 9 unique random integers between 1 and 50
imaginary_parts.append(0)  # Ensure one value is 0
imaginary_parts.sort()  # Sort in increasing order

s_values = [complex(real_part, imag) for imag in imaginary_parts]

print("Generated s-values (sorted by increasing imaginary part):")
for idx, s in enumerate(s_values, start=1):
    print(f"s{idx} = {s}")

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Functions to compute Re(S_p) and Im(S_p) for a given s
def compute_S_p_parts(s):
    S_real = []  # Store the real part of S_p for each p
    S_imag = []  # Store the imaginary part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        S_imag_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
                S_imag_p += legendre * magnitude * np.sin(theta)  # Imaginary part: sum of sines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)
        S_imag.append(S_imag_p)

    # Ensure all elements in S_real and S_imag are floats
    S_real_float = []
    S_imag_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value in Re(S_p): {val}")

    for val in S_imag:
        try:
            S_imag_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value in Im(S_p): {val}")

    # Convert to NumPy arrays for further processing
    S_real_float = np.array(S_real_float)
    S_imag_float = np.array(S_imag_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]
    finite_S_imag = S_imag_float[np.isfinite(S_imag_float)]

    return finite_S_real, finite_S_imag

# Compute S_p and plot for each s value
for idx, s in enumerate(s_values, start=1):
    finite_S_real, finite_S_imag = compute_S_p_parts(s)

    if len(finite_S_real) == 0 and len(finite_S_imag) == 0:
        print(f"No valid data to plot for s{idx} = {s}.")
        continue

    # Plot histogram of the real part of S_p for the current s
    if len(finite_S_real) > 0:
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Re(S_p) for s{idx} = {s}")
        plt.xlabel("Re(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_real = np.mean(finite_S_real)
        std_real = np.std(finite_S_real)
        print(f"Mean of Re(S_p) for s{idx}: {mean_real}")
        print(f"Standard deviation of Re(S_p) for s{idx}: {std_real}")

    # Plot histogram of the imaginary part of S_p for the current s
    if len(finite_S_imag) > 0:
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_imag, bins=100, color='green', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Im(S_p) for s{idx} = {s}")
        plt.xlabel("Im(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_imag = np.mean(finite_S_imag)
        std_imag = np.std(finite_S_imag)
        print(f"Mean of Im(S_p) for s{idx}: {mean_imag}")
        print(f"Standard deviation of Im(S_p) for s{idx}: {std_imag}")
# Out:
# Enter a large value for X: 1000000
# Enter the real part of s: 0
# Generated s-values (sorted by increasing imaginary part):
# s1 = 0j
# s2 = 10j
# s3 = 11j
# s4 = 16j
# s5 = 22j
# s6 = 27j
# s7 = 32j
# s8 = 44j
# s9 = 45j
# s10 = 47j
# Number of primes in the range [1000000, 2000000]: 70435
# Mean of Re(S_p) for s1: 9.957237169021083
# Standard deviation of Re(S_p) for s1: 14.361978229356533
# Mean of Im(S_p) for s1: 0.0
# Standard deviation of Im(S_p) for s1: 0.0
# Mean of Re(S_p) for s2: -0.018793003285856792
# Standard deviation of Re(S_p) for s2: 6.52334465327273
# Mean of Im(S_p) for s2: -2.313708094800268
# Standard deviation of Im(S_p) for s2: 6.392083358456471
# Mean of Re(S_p) for s3: 1.2185134276326655
# Standard deviation of Re(S_p) for s3: 5.714975072980937
# Mean of Im(S_p) for s3: 1.424903749109885
# Standard deviation of Im(S_p) for s3: 5.487172708089277
# Mean of Re(S_p) for s4: 1.3718365373744466
# Standard deviation of Re(S_p) for s4: 5.103187575971034
# Mean of Im(S_p) for s4: -0.15477674168000302
# Standard deviation of Im(S_p) for s4: 5.331916505544395
# Mean of Re(S_p) for s5: -1.768651542624849
# Standard deviation of Re(S_p) for s5: 7.51643649431053
# Mean of Im(S_p) for s5: 1.734540726380815
# Standard deviation of Im(S_p) for s5: 7.496354838335137
# Mean of Re(S_p) for s6: 3.097645244658197
# Standard deviation of Re(S_p) for s6: 7.1143868532915535
# Mean of Im(S_p) for s6: 4.045225204343031
# Standard deviation of Im(S_p) for s6: 6.951531186143782
# Mean of Re(S_p) for s7: 1.3907956325145896
# Standard deviation of Re(S_p) for s7: 7.7104273439310855
# Mean of Im(S_p) for s7: -4.572505057160691
# Standard deviation of Im(S_p) for s7: 9.471846328959666
# Mean of Re(S_p) for s8: -0.19079656999636657
# Standard deviation of Re(S_p) for s8: 5.397871946834289
# Mean of Im(S_p) for s8: -2.2140941381742496
# Standard deviation of Im(S_p) for s8: 6.045980552075706
# Mean of Re(S_p) for s9: 3.810409208461188
# Standard deviation of Re(S_p) for s9: 7.906345273942572
# Mean of Im(S_p) for s9: 4.363944306846808
# Standard deviation of Im(S_p) for s9: 9.52806703492049
# Mean of Re(S_p) for s10: 1.8359724721415964
# Standard deviation of Re(S_p) for s10: 5.244307889266561
# Mean of Im(S_p) for s10: -0.5268534857563071
# Standard deviation of Im(S_p) for s10: 5.527375139012695

# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt
from sympy.functions.combinatorial.numbers import legendre_symbol
import random

# Define parameters
X = int(input("Enter a large value for X: "))  # User input for X
real_part = float(input("Enter the real part of s: "))  # User input for the real part of s
K = 100

# Generate 10 different s-values with imaginary parts between 0 and 50
imaginary_parts = random.sample(range(1, 51), 9)  # Pick 9 unique random integers between 1 and 50
imaginary_parts.append(0)  # Ensure one value is 0
imaginary_parts.sort()  # Sort in increasing order

s_values = [complex(real_part, imag) for imag in imaginary_parts]

print("Generated s-values (sorted by increasing imaginary part):")
for idx, s in enumerate(s_values, start=1):
    print(f"s{idx} = {s}")

# Generate all primes in the range [X, 2X]
all_primes = list(sympy.primerange(X, 2 * X))
num_primes = len(all_primes)

if num_primes == 0:
    print(f"No primes found in the range [{X}, {2 * X}].")
    exit()

print(f"Number of primes in the range [{X}, {2 * X}]: {num_primes}")

# Functions to compute Re(S_p) and Im(S_p) for a given s
def compute_S_p_parts(s):
    S_real = []  # Store the real part of S_p for each p
    S_imag = []  # Store the imaginary part of S_p for each p

    for p in all_primes:
        S_real_p = 0
        S_imag_p = 0
        for k in range(1, K + 1):
            try:
                legendre = legendre_symbol(k, p)
                theta = -s.imag * np.log(k)  # Extract the imaginary part of s
                magnitude = k ** (-s.real)  # Extract the real part of s
                S_real_p += legendre * magnitude * np.cos(theta)  # Real part: sum of cosines
                S_imag_p += legendre * magnitude * np.sin(theta)  # Imaginary part: sum of sines
            except Exception as e:
                print(f"Error at p={p}, k={k}: {e}")
                continue
        S_real.append(S_real_p)
        S_imag.append(S_imag_p)

    # Ensure all elements in S_real and S_imag are floats
    S_real_float = []
    S_imag_float = []
    for val in S_real:
        try:
            S_real_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value in Re(S_p): {val}")

    for val in S_imag:
        try:
            S_imag_float.append(float(val))
        except (TypeError, ValueError):
            print(f"Skipping non-numeric value in Im(S_p): {val}")

    # Convert to NumPy arrays for further processing
    S_real_float = np.array(S_real_float)
    S_imag_float = np.array(S_imag_float)

    # Filter out invalid (non-finite) values
    finite_S_real = S_real_float[np.isfinite(S_real_float)]
    finite_S_imag = S_imag_float[np.isfinite(S_imag_float)]

    return finite_S_real, finite_S_imag

# Compute S_p and plot for each s value
for idx, s in enumerate(s_values, start=1):
    finite_S_real, finite_S_imag = compute_S_p_parts(s)

    if len(finite_S_real) == 0 and len(finite_S_imag) == 0:
        print(f"No valid data to plot for s{idx} = {s}.")
        continue

    # Plot histogram of the real part of S_p for the current s
    if len(finite_S_real) > 0:
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_real, bins=100, color='blue', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Re(S_p) for s{idx} = {s}")
        plt.xlabel("Re(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_real = np.mean(finite_S_real)
        std_real = np.std(finite_S_real)
        print(f"Mean of Re(S_p) for s{idx}: {mean_real}")
        print(f"Standard deviation of Re(S_p) for s{idx}: {std_real}")

    # Plot histogram of the imaginary part of S_p for the current s
    if len(finite_S_imag) > 0:
        plt.figure(figsize=(10, 6))
        plt.hist(finite_S_imag, bins=100, color='green', alpha=0.7, edgecolor='black')
        plt.title(f"Distribution of Im(S_p) for s{idx} = {s}")
        plt.xlabel("Im(S_p)")
        plt.ylabel("Frequency")
        plt.grid(True)
        plt.show()

        # Basic statistical analysis
        mean_imag = np.mean(finite_S_imag)
        std_imag = np.std(finite_S_imag)
        print(f"Mean of Im(S_p) for s{idx}: {mean_imag}")
        print(f"Standard deviation of Im(S_p) for s{idx}: {std_imag}")
# Out:
# Enter a large value for X: 3000000
# Enter the real part of s: 0
# Generated s-values (sorted by increasing imaginary part):
# s1 = 0j
# s2 = 7j
# s3 = 8j
# s4 = 21j
# s5 = 28j
# s6 = 29j
# s7 = 39j
# s8 = 40j
# s9 = 44j
# s10 = 49j
# Number of primes in the range [3000000, 6000000]: 196033
# Mean of Re(S_p) for s1: 9.984369978524024
# Standard deviation of Re(S_p) for s1: 14.4237386973343
# Mean of Im(S_p) for s1: 0.0
# Standard deviation of Im(S_p) for s1: 0.0
# Mean of Re(S_p) for s2: 0.36856161537524124
# Standard deviation of Re(S_p) for s2: 5.201335330620846
# Mean of Im(S_p) for s2: -0.24647187817115004
# Standard deviation of Im(S_p) for s2: 4.83414716852894
# Mean of Re(S_p) for s3: 0.811108649333728
# Standard deviation of Re(S_p) for s3: 6.020451220354385
# Mean of Im(S_p) for s3: 2.5745436517430234
# Standard deviation of Im(S_p) for s3: 7.954766135470545
# Mean of Re(S_p) for s4: 1.3628848550385506
# Standard deviation of Re(S_p) for s4: 4.910927937544852
# Mean of Im(S_p) for s4: 0.8963610530815307
# Standard deviation of Im(S_p) for s4: 5.646293053417684
# Mean of Re(S_p) for s5: -1.8914547743058252
# Standard deviation of Re(S_p) for s5: 5.934816223864375
# Mean of Im(S_p) for s5: -1.3449136376246764
# Standard deviation of Im(S_p) for s5: 7.289100630409008
# Mean of Re(S_p) for s6: 1.8473150465131418
# Standard deviation of Re(S_p) for s6: 5.482746523514183
# Mean of Im(S_p) for s6: -2.0718141599630746
# Standard deviation of Im(S_p) for s6: 5.958936752361358
